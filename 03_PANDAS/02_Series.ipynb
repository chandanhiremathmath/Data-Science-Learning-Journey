# %% [markdown]
# # 1️⃣ Introduction
#
# A **Series** is a one-dimensional labeled array provided by the Pandas library.
#
# It can store:
#
# - Integers
# - Floating-point numbers
# - Strings
# - Boolean values
# - Dates
# - Python objects
#
# Unlike a normal Python list, every value in a Series has an associated **index**, making data retrieval faster and more organized.
#
# You can think of a Series as a single column in an Excel sheet or a single column of a database table.

# %% [markdown]
# # 2️⃣ Problem Statement
#
# Suppose a teacher has marks of students.
#
# | Student | Marks |
# |---------|------|
# | Rahul | 92 |
# | Priya | 87 |
# | Amit | 78 |
# | Sneha | 95 |
# | Kiran | 84 |
#
# The teacher wants to answer questions such as:
#
# - What is the average mark?
# - Who scored the highest?
# - How many students scored above 90?
# - What is the maximum mark?
# - Sort the marks in ascending order.
#
# Using Python lists, these operations require multiple loops and additional code.
#
# Pandas Series provides built-in methods to perform these tasks efficiently.

# %% [markdown]
# # 3️⃣ What is a Pandas Series?
#
# A **Series** is a one-dimensional data structure that stores:
#
# - Values
# - Corresponding Index
#
# Every element in a Series has:
#
# 1. A value
# 2. An index
#
# Example:
#
# | Index | Value |
# |------|------|
# |0|92|
# |1|87|
# |2|78|
# |3|95|
# |4|84|
#
# The index acts like the address of each value, allowing quick and efficient access.

# %% [markdown]
# # 💡 Real-World Analogy
#
# Imagine your college attendance register.
#
# | Roll No | Student |
# |----------|----------|
# |101|Rahul|
# |102|Priya|
# |103|Amit|
# |104|Sneha|
#
# Here,
#
# - Roll Number acts as the **Index**
# - Student Name acts as the **Value**
#
# A Pandas Series works in exactly the same way.
#
# Every value is associated with an index.

# %% [markdown]
# # 4️⃣ Why Do We Need Series?
#
# Before Pandas, programmers mainly used Python lists.
#
# Lists work well for small programs, but they become inefficient when dealing with large datasets.
#
# Series provides several advantages:
#
# - Fast indexing
# - Built-in statistical methods
# - Better memory organization
# - Easy filtering
# - Automatic handling of missing values
# - Seamless integration with DataFrames
#
# Series serves as the building block of a Pandas DataFrame.

# %% [markdown]
# # 5️⃣ Difference Between List, NumPy Array, and Pandas Series
#
# | Feature | Python List | NumPy Array | Pandas Series |
# |----------|-------------|-------------|---------------|
# |Index|✅|✅|✅|
# |Stores Different Data Types|✅|❌|✅|
# |Fast Mathematical Operations|❌|✅|✅|
# |Labels (Custom Index)|❌|❌|✅|
# |Missing Value Handling|❌|❌|✅|
# |Data Analysis|❌|❌|✅|
# |Built-in Statistical Functions|Limited|Some|Extensive|

# %% [markdown]
# # 6️⃣ Importing Pandas
#
# Before creating a Series, we need to import the Pandas library.

# %%
import pandas as pd

# %% [markdown]
# # 7️⃣ Creating a Series
#
# Pandas allows us to create a Series from various Python data structures.
#
# Common sources include:
#
# - List
# - Tuple
# - Dictionary
# - NumPy Array
# - Scalar Value
#
# Let's explore each one with examples.

# %% [markdown]
# ## 7.1 Creating a Series from a Python List
#
# A Python list is the most common way to create a Series.
#
# By default, Pandas assigns integer indexes starting from 0.

# %%
import pandas as pd

marks = [92, 87, 78, 95, 84]

series_marks = pd.Series(marks)

series_marks
# Out:
# 0    92
# 1    87
# 2    78
# 3    95
# 4    84
# dtype: int64

# %% [markdown]
# ### Explanation
#
# - Left side → Index
# - Right side → Values
# - `dtype` → Data type of stored values

# %% [markdown]
# ## Why use a Series instead of a List?
#
# Python List
#
# ```python
# marks = [92,87,78,95]
# ```
#
# Pandas Series
#
# ```python
# marks = pd.Series([92,87,78,95])
# ```
#
# Series provides many built-in methods such as:
#
# - mean()
# - max()
# - min()
# - sum()
# - count()
# - sort_values()
#
# These operations would require additional loops or functions when using a plain Python list.

# %% [markdown]
# ## 7.2 Creating a Series from a Tuple
#
# A tuple is immutable, but Pandas can still convert it into a Series.

# %%
numbers = (10, 20, 30, 40)

pd.Series(numbers)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %% [markdown]
# ### Explanation
#
# Although tuples cannot be modified, the created Series behaves like a normal Pandas Series.
#
# The original tuple remains unchanged.

# %% [markdown]
# ## 7.3 Creating a Series from a Dictionary
#
# When creating a Series from a dictionary:
#
# - Keys become the index.
# - Values become the data.

# %%
students = {
    "Rahul":92,
    "Priya":87,
    "Amit":78,
    "Sneha":95
}

student_marks = pd.Series(students)

student_marks
# Out:
# Rahul    92
# Priya    87
# Amit     78
# Sneha    95
# dtype: int64

# %% [markdown]
# ## Industry Usage
#
# This method is useful when data already exists in key-value format.
#
# Examples:
#
# - Employee ID → Salary
# - Product ID → Price
# - Student ID → Marks

# %% [markdown]
# ## 7.4 Creating a Series from a NumPy Array
#
# Since Pandas is built on top of NumPy, NumPy arrays can easily be converted into a Series.

# %%
import numpy as np

array = np.array([100,200,300,400])

pd.Series(array)
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64

# %% [markdown]
# ### Why is this useful?
#
# Many Machine Learning libraries produce NumPy arrays.
#
# Pandas allows us to convert them into Series for easier analysis.

# %% [markdown]
# ## 7.5 Creating a Series from a Scalar Value
#
# A scalar value is a single value.
#
# When a scalar is used, the index must be specified.

# %%
pd.Series(100, index=[0,1,2,3,4])
# Out:
# 0    100
# 1    100
# 2    100
# 3    100
# 4    100
# dtype: int64

# %% [markdown]
# # 8️⃣ Custom Index
#
# By default, Pandas assigns indexes automatically.
#
# We can also specify our own indexes.

# %%
marks = [92,87,78,95]

students = ["Rahul","Priya","Amit","Sneha"]

series = pd.Series(marks,index=students)

series
# Out:
# Rahul    92
# Priya    87
# Amit     78
# Sneha    95
# dtype: int64

# %% [markdown]
# ## Why are Custom Indexes Useful?
#
# Examples:
#
# Customer ID
#
# Employee ID
#
# Product ID
#
# Roll Number
#
# Country Name
#
# These are much more meaningful than numeric indexes.

# %% [markdown]
# # 9️⃣ Understanding Series Attributes
#
# Once a Series is created, Pandas provides several built-in attributes that help us understand its structure.
#
# These attributes allow us to answer questions such as:
#
# - What type of data is stored?
# - How many elements are present?
# - What are the indexes?
# - What is the shape of the Series?
# - Is it one-dimensional?
#
# Understanding these attributes is an essential first step before performing any data analysis.

# %%
import pandas as pd

students = pd.Series(
    [92, 87, 78, 95, 84],
    index=["Rahul", "Priya", "Amit", "Sneha", "Kiran"],
    name="Marks"
)

students
# Out:
# Rahul    92
# Priya    87
# Amit     78
# Sneha    95
# Kiran    84
# Name: Marks, dtype: int64

# %% [markdown]
# # 9.1 index
#
# The **index** attribute returns the labels associated with each value in the Series.
#
# Think of the index as the "address" of every value.
#
# Unlike Python lists, the indexes can be customized to meaningful labels such as employee IDs, product IDs, or student names.

# %%
students.index
# Out:
# Index(['Rahul', 'Priya', 'Amit', 'Sneha', 'Kiran'], dtype='str')

# %% [markdown]
# ### Expected Output
#
# ```
# Index(['Rahul', 'Priya', 'Amit', 'Sneha', 'Kiran'], dtype='object')
# ```
#
# ### Explanation
#
# The output shows the labels (indexes) assigned to each value.
#
# These indexes help retrieve values quickly without relying only on numeric positions.

# %% [markdown]
# ### Real Industry Usage
#
# Instead of numeric indexes, industries often use:
#
# - Employee IDs
# - Customer IDs
# - Product IDs
# - Roll Numbers
# - Transaction IDs
#
# Meaningful indexes improve readability and make data analysis easier.

# %% [markdown]
# # 9.2 values
#
# The **values** attribute returns the actual data stored in the Series as a NumPy array.
#
# This is useful when you need to perform NumPy operations or interact with libraries that expect arrays.

# %%
students.values
# Out:
# array([92, 87, 78, 95, 84])

# %% [markdown]
# # 9.3 dtype
#
# The **dtype** attribute tells us the data type of the values stored inside the Series.
#
# Knowing the data type is important because many operations depend on it.

# %%
students.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ### Expected Output
#
# ```
# dtype('int64')
# ```
#
# ### Explanation
#
# All values are integers.
#
# Therefore, Pandas stores them as **int64**.
#
# Other possible data types include:
#
# - float64
# - object
# - bool
# - datetime64

# %% [markdown]
# # 9.4 shape
#
# The **shape** attribute tells us the dimensions of the Series.
#
# Since a Series is one-dimensional, the shape contains only one value.

# %%
students.shape
# Out:
# (5,)

# %% [markdown]
# ### Expected Output
#
# ```
# (5,)
# ```
#
# ### Explanation
#
# The Series contains **5 elements**.
#
# The comma indicates that this is a one-dimensional structure.

# %% [markdown]
# # 9.5 size
#
# The **size** attribute returns the total number of elements present in the Series.

# %%
students.size
# Out:
# 5

# %% [markdown]
# ### Expected Output
#
# ```
# 5
# ```
#
# Unlike `shape`, `size` returns only the number of elements.

# %% [markdown]
# # 9.6 ndim
#
# The **ndim** attribute returns the number of dimensions of the Series.

# %%
students.ndim
# Out:
# 1

# %% [markdown]
# ### Expected Output
#
# ```
# 1
# ```
#
# ### Explanation
#
# A Series always has **one dimension**.
#
# A DataFrame, on the other hand, has **two dimensions**.

# %% [markdown]
# # 9.7 name
#
# The **name** attribute returns the name assigned to the Series.
#
# Giving meaningful names improves readability, especially when multiple Series are combined into a DataFrame.

# %%
students.name
# Out:
# 'Marks'

# %% [markdown]
# ### Expected Output
#
# ```
# 'Marks'
# ```
#
# The name of this Series is **Marks**, which we assigned while creating it.

# %% [markdown]
# # 📊 Summary of Series Attributes
#
# | Attribute | Description | Returns |
# |------------|-------------|----------|
# | index | Labels of the Series | Index Object |
# | values | Data stored in the Series | NumPy Array |
# | dtype | Data type of values | Data Type |
# | shape | Dimensions | Tuple |
# | size | Number of elements | Integer |
# | ndim | Number of dimensions | Integer |
# | name | Name of the Series | String |

# %% [markdown]
# ## Difference Between `shape` and `ndim`
#
# ### `ndim`
#
# **Question:**
#
# > How many dimensions does this object have?
#
# Example:
#
# ```python
# students.ndim
# ```
#
# Output
#
# ```python
# 1
# ```
#
# Meaning:
#
# The Series has only **one dimension**.
#
# ---
#
# ### `shape`
#
# **Question:**
#
# > What is the size of each dimension?
#
# Example:
#
# ```python
# students.shape
# ```
#
# Output
#
# ```python
# (5,)
# ```
#
# Meaning:
#
# There is **1 dimension**, and it contains **5 elements**.
#
# ---
#
# ### Comparison
#
# | Attribute | Question it Answers | Example |
# |------------|--------------------|----------|
# | `ndim` | How many dimensions? | `1` |
# | `shape` | What is the size of each dimension? | `(5,)` |
# | `size` | Total number of elements? | `5` |
#
# ---
#
# ### 🧠 Memory Trick
#
# Remember:
#
# - **ndim → Number of Dimensions**
# - **shape → Size of each Dimension**
# - **size → Total number of values**

# %% [markdown]
# # 🔟 Accessing Data in a Series
#
# Creating a Series is only the first step.
#
# To analyze data effectively, we need to retrieve specific values from the Series.
#
# Pandas provides multiple ways to access data:
#
# - Square Brackets `[]`
# - Label-based Indexing `.loc[]`
# - Position-based Indexing `.iloc[]`
#
# Choosing the correct method improves code readability and helps avoid common indexing mistakes.

# %%
import pandas as pd

students = pd.Series(
    [92,87,78,95,84],
    index=["Rahul","Priya","Amit","Sneha","Kiran"],
    name="Marks"
)

students
# Out:
# Rahul    92
# Priya    87
# Amit     78
# Sneha    95
# Kiran    84
# Name: Marks, dtype: int64

# %% [markdown]
# # 10.1 Accessing Data Using Square Brackets `[]`
#
# Square brackets are the simplest way to retrieve data from a Series.
#
# Depending on the type of index used, they can retrieve values by:
#
# - Label
# - Position (when default integer index is present)
#
# However, for clarity and consistency, `.loc[]` and `.iloc[]` are generally preferred.

# %%
students["Rahul"]
# Out:
# np.int64(92)

# %% [markdown]
# Index
#
# Rahul
#
# ↓
#
# Value
#
# 92

# %%
students["Sneha"]
# Out:
# np.int64(95)

# %% [markdown]
# ## Why use labels instead of positions?
#
# Imagine your Series contains employee salaries.
#
# Accessing:
#
# ```python
# salary["EMP1023"]
# ```
#
# is much more meaningful than:
#
# ```python
# salary[57]
# ```
#
# Meaningful labels improve code readability.

# %% [markdown]
# # 10.2 Accessing Multiple Values

# %%
students[["Rahul","Kiran","Priya"]]
# Out:
# Rahul    92
# Kiran    84
# Priya    87
# Name: Marks, dtype: int64

# %% [markdown]
# Explanation
#
# Passing a list of labels returns another Series containing only those values.

# %% [markdown]
# # 10.3 Accessing Using Position (iloc)

# %% [markdown]
# `.iloc[]` stands for **Integer Location**.
#
# It accesses values based on their **position**, starting from **0**.
#
# Use `.iloc[]` when you know the position of the data instead of its label.

# %% [markdown]
# Position
#
# 0 → Rahul
#
# 1 → Priya
#
# 2 → Amit
#
# 3 → Sneha
#
# 4 → Kiran

# %%
students.iloc[0]
# Out:
# np.int64(92)

# %%
students.iloc[3]
# Out:
# np.int64(95)

# %% [markdown]
# # 10.4 Accessing Using Labels (loc)

# %% [markdown]
# `.loc[]` stands for **Location**.
#
# It retrieves data using the **index label**, not the position.
#
# Whenever your Series has meaningful indexes such as names or IDs, `.loc[]` is the recommended approach.

# %%
students.loc["Amit"]
# Out:
# np.int64(78)

# %%
students.loc["Priya"]
# Out:
# np.int64(87)

# %% [markdown]
# | `.loc[]`      | `.iloc[]`         |
# | ------------- | ----------------- |
# | Uses Labels   | Uses Positions    |
# | Employee ID   | Employee Number   |
# | Student Name  | Row Number        |
# | String Labels | Integer Positions |

# %% [markdown]
# # 10.5 Negative Indexing
#
# Just like Python lists, .iloc[] supports negative indexing.

# %%
students.iloc[-1]
# Out:
# np.int64(84)

# %% [markdown]
# -1
#
# ↓
#
# Last Element
#
# ↓
#
# Kiran
#
# ↓
#
# 84

# %% [markdown]
# # 10.6 Slicing

# %%
students.iloc[1:4]
# Out:
# Priya    87
# Amit     78
# Sneha    95
# Name: Marks, dtype: int64

# %% [markdown]
# Start
#
# ↓
#
# 1
#
# Included
#
# End
#
# ↓
#
# 4
#
# Excluded

# %%
students.loc["Priya":"Sneha"]
# Out:
# Priya    87
# Amit     78
# Sneha    95
# Name: Marks, dtype: int64

# %% [markdown]
# # 🚨 Very Important Difference
#
#
# | `.iloc[]`       | `.loc[]`        |
# | --------------- | --------------- |
# | End is Excluded | End is Included |

# %%
students.iloc[1:4]
# Out:
# Priya    87
# Amit     78
# Sneha    95
# Name: Marks, dtype: int64

# %%
students.loc["Priya":"Sneha"]
#Notice Sneha is included.
# Out:
# Priya    87
# Amit     78
# Sneha    95
# Name: Marks, dtype: int64

# %% [markdown]
# # 1️⃣1️⃣ Updating Values in a Series
#
# A Series is mutable, which means its values can be modified after creation.
#
# Pandas allows updating values using:
#
# - Label (`.loc[]`)
# - Position (`.iloc[]`)
# - Square Brackets (`[]`)
#
# Updating values is commonly required while cleaning datasets, correcting mistakes, or replacing outdated information.

# %%
import pandas as pd

students = pd.Series(
    [92,87,78,95,84],
    index=["Rahul","Priya","Amit","Sneha","Kiran"],
    name="Marks"
)

students
# Out:
# Rahul    92
# Priya    87
# Amit     78
# Sneha    95
# Kiran    84
# Name: Marks, dtype: int64

# %% [markdown]
# ## 11.1 Updating Using Label
#
# When we know the label (index), we can update the value directly.
#
# This is the safest and most readable approach.

# %%
students["Rahul"] = 98

students
# Out:
# Rahul    98
# Priya    87
# Amit     78
# Sneha    95
# Kiran    84
# Name: Marks, dtype: int64

# %% [markdown]
# # Industry Usage
#
# Suppose a student's marks were entered incorrectly.
#
# Instead of recreating the Series, we simply update the value.
#
# Similarly,
#
# - Updating employee salaries
# - Correcting product prices
# - Fixing sensor readings

# %% [markdown]
# ## 11.2 Updating Using `.loc[]`
#
# `.loc[]` updates values using index labels.
#
# This is the recommended approach when working with meaningful labels.

# %%
students.loc["Priya"] = 91

students
# Out:
# Rahul    98
# Priya    91
# Amit     78
# Sneha    95
# Kiran    84
# Name: Marks, dtype: int64

# %% [markdown]
# ## 11.3 Updating Using `.iloc[]`
#
# `.iloc[]` updates values using integer positions.
#
# Use this when the row position is known.

# %%
students.iloc[2] = 80

students
# Out:
# Rahul    98
# Priya    91
# Amit     80
# Sneha    95
# Kiran    84
# Name: Marks, dtype: int64

# %% [markdown]
# ## 11.4 Updating Multiple Values

# %%
students[["Rahul","Sneha"]] = [100,99]

students
# Out:
# Rahul    100
# Priya     91
# Amit      80
# Sneha     99
# Kiran     84
# Name: Marks, dtype: int64

# %% [markdown]
# ### How does this work?
#
# The first value (100) is assigned to Rahul.
#
# The second value (99) is assigned to Sneha.
#
# The number of new values must match the number of selected indexes.

# %% [markdown]
# ## ⚠️ Common Beginner Mistake

# %%
# students[["Rahul","Sneha"]] = [100]

# ValueError:
# cannot set using a list-like indexer with a different length than the value

# %% [markdown]
# Selected
#
# ↓
#
# 2 Students
#
# Given
#
# ↓
#
# 1 Value
#
# Pandas doesn't know what value to assign to the second student.

# %%
# Correct Solution

students[["Rahul","Sneha"]] = [100,99]

# %% [markdown]
# ## Pros
#
# ✔ Easy to modify data
#
# ✔ Cleaner than loops
#
# ✔ Supports label and position based updates
#
# ✔ Useful during data cleaning

# %% [markdown]
# ## Cons
#
# ❌ Accidentally overwrites existing data
#
# ❌ Wrong labels create new rows in some situations
#
# ❌ Position changes may affect updates

# %% [markdown]
# ## Edge Cases

# %%
students["Arjun"] = 88

students
# Out:
# Rahul    100
# Priya     91
# Amit      80
# Sneha     99
# Kiran     84
# Arjun     88
# Name: Marks, dtype: int64

# %% [markdown]
# # Explanation
#
# Pandas automatically creates a new index.
#
# Many beginners expect an error.
#
# Instead,
#
# Pandas adds a new entry.

# %% [markdown]
# ## 🏭 Real Industry Usage
#
# Updating values is common in:
#
# - Banking (correcting transaction records)
# - Healthcare (updating patient reports)
# - E-commerce (changing product prices)
# - HR (salary revisions)
# - Schools (mark corrections)## 🏭 Real Industry Usage

# %% [markdown]
# ### Interview Questions
#
# 1. Is a Pandas Series mutable?
#
# 2. Difference between updating using `loc` and `iloc`?
#
# 3. What happens if a new label is assigned?
#
# 4. Does updating change the original Series?
#
# 5. Which is safer: `loc` or `iloc`?

# %% [markdown]
# # Assignment
#
# 1. Create a Series of five employees.
#
# 2. Update the salary of one employee.
#
# 3. Increase salaries of two employees.
#
# 4. Add a new employee.
#
# 5. Print the final Series.

# %% [markdown]
# # Mini Challenge
#
# Create a Series containing cricket player scores.
#
# Perform the following:
#
# ✔ Update one player's score.
#
# ✔ Add a new player.
#
# ✔ Increase two players' scores.
#
# ✔ Display the updated Series.

# %% [markdown]
# # 1️⃣2️⃣ Exploring Series Using Statistical Methods
#
# After creating and updating a Series, the next step is to analyze the data.
#
# Pandas provides several built-in statistical methods that help summarize and understand the dataset without writing loops.
#
# These methods are commonly used in:
#
# - Data Analysis
# - Machine Learning
# - Business Intelligence
# - Reporting
# - Dashboard Development

# %%
import pandas as pd

students = pd.Series(
    [92, 87, 78, 95, 84],
    index=["Rahul", "Priya", "Amit", "Sneha", "Kiran"],
    name="Marks"
)

students
# Out:
# Rahul    92
# Priya    87
# Amit     78
# Sneha    95
# Kiran    84
# Name: Marks, dtype: int64

# %% [markdown]
# # 12.1 head()
#
# ## 📖 Definition
#
# `head()` returns the first **n** rows of a Series.
#
# By default, it returns the first **5** rows.
#
# ---
#
# ## 🤔 Why do we need it?
#
# When working with large datasets containing thousands or millions of rows, displaying the entire dataset is impractical.
#
# `head()` allows us to quickly inspect the beginning of the dataset.

# %%
students.head()
# Out:
# Rahul    92
# Priya    87
# Amit     78
# Sneha    95
# Kiran    84
# Name: Marks, dtype: int64

# %%
students.head(3)
# Out:
# Rahul    92
# Priya    87
# Amit     78
# Name: Marks, dtype: int64

# %% [markdown]
# students.head("3")
#
#
# ### ❌ Error
#
# ```
# TypeError
# ```
#
# ### Why?
#
# `head()` expects an integer.
#
# Instead, a string `"3"` was passed.
#
# ### ✅ Correct Solution
#
# ```python
# students.head(3)
# ```

# %% [markdown]
# ### 👍 Pros
#
# - Fast preview of data
# - Useful for large datasets
# - Helps verify whether data loaded correctly
#
# ### 👎 Cons
#
# - Doesn't show the entire dataset
# - May not reveal issues occurring later in the data
#
# ### 🏢 Real Industry Usage
#
# After reading a CSV file, Data Analysts almost always call:
#
# ```python
# df.head()
# ```
#
# to verify that the data has loaded correctly.
#
# ### 🧠 Interview Question
#
# **Q:** What is the default number of rows returned by `head()`?
#
# **Answer:** 5

# %% [markdown]
# # 12.2 tail()
#
# ## 📖 Definition
#
# `tail()` returns the last **n** rows of a Series.
#
# By default, it returns the last **5** rows.

# %%
students.tail()
# Out:
# Rahul    92
# Priya    87
# Amit     78
# Sneha    95
# Kiran    84
# Name: Marks, dtype: int64

# %%
students.tail(2)
# Out:
# Sneha    95
# Kiran    84
# Name: Marks, dtype: int64

# %% [markdown]
# ### 🏢 Real Industry Usage
#
# Suppose a company receives **5 lakh customer transactions** every day.
#
# To inspect the latest records, analysts use:
#
# ```python
# df.tail()
# ```

# %% [markdown]
# # 12.3 sample()
#
# ## 📖 Definition
#
# `sample()` returns random records from the Series.
#
# This is useful for checking random portions of large datasets.

# %%
students.sample()
# Out:
# Amit    78
# Name: Marks, dtype: int64

# %%
students.sample(2)
# Out:
# Rahul    92
# Amit     78
# Name: Marks, dtype: int64

# %% [markdown]
# ### 📤 Expected Output
#
# The output changes every time because rows are selected randomly.
#
# Example:
#
# ```
# Priya    87
# Kiran    84
# ```
#
# or
#
# ```
# Rahul    92
# Sneha    95
# ```
#
# ### 🔍 Explanation
#
# Every execution may produce different rows.
#
# This is expected behavior.

# %%
students.sample(2, random_state=42)
# Out:
# Priya    87
# Kiran    84
# Name: Marks, dtype: int64

# %% [markdown]
# ## 🤔 Why use `random_state`?
#
# Without `random_state`, the output changes every execution.
#
# Using a fixed value ensures reproducible results, which is especially useful during debugging, assignments, and machine learning experiments.

# %% [markdown]
# students.sample(10)
#
# ### ❌ Error
#
# ```
# ValueError:
# Cannot take a larger sample than population
# ```
#
# ### Why?
#
# The Series contains only **5** elements, but we requested **10**.
#
# ### ✅ Correct Solution
#
# ```python
# students.sample(5)
# ```
#
# or
#
# ```python
# students.sample(10, replace=True)
# ```

# %% [markdown]
# ### 👍 Pros
#
# - Randomly inspects data
# - Useful for quality checks
# - Helpful during machine learning experiments
#
# ### 👎 Cons
#
# - Output changes every execution unless `random_state` is used.
#
# ### 🏢 Real Industry Usage
#
# Data Scientists often inspect random records before cleaning data to avoid bias.
#
# ### 🧠 Interview Question
#
# **Q:** Why do we use `random_state` in `sample()`?
#
# **Answer:** To produce the same random output every time the code runs.

# %% [markdown]
# # 12.4 count()
#
# ## 📖 Definition
#
# The `count()` method returns the total number of **non-missing (non-null)** values present in a Series.
#
# Unlike Python's `len()`, `count()` ignores missing values (`NaN`).
#
# ---
#
# ## 🤔 Why do we need it?
#
# Before performing any analysis, we should know how many valid observations are available.
#
# This helps us:
#
# - Check data completeness
# - Detect missing values
# - Verify the dataset before applying Machine Learning algorithms
#
# ---
#
# ## 🧠 Think Like a Data Analyst
#
# Imagine you collected marks of 100 students.
#
# Some students were absent, so their marks are missing (`NaN`).
#
# If you calculate the average, you should only consider students who actually have marks.
#
# `count()` tells you exactly how many valid records are available.

# %%
import pandas as pd
import numpy as np

students = pd.Series(
    [92, 87, 78, 95, np.nan],
    index=["Rahul", "Priya", "Amit", "Sneha", "Kiran"],
    name="Marks"
)

students
# Out:
# Rahul    92.0
# Priya    87.0
# Amit     78.0
# Sneha    95.0
# Kiran     NaN
# Name: Marks, dtype: float64

# %%
students.count()
# Out:
# np.int64(4)

# %%
len(students)
# Out:
# 5

# %% [markdown]
# ### 📤 Expected Output
#
# ```
# 4
# ```
#
# ---
#
# ### 🔍 Explanation
#
# Our Series contains **5 students**.
#
# However,
#
# Kiran's marks are missing (`NaN`).
#
# `count()` ignores missing values.
#
# Therefore,
#
# Valid Marks = **4**

# %% [markdown]
# ### ⚡ Difference Between `count()` and `len()`
#
# | `count()` | `len()` |
# |------------|----------|
# | Counts only non-null values | Counts all values |
# | Ignores NaN | Includes NaN |
# | Used in Data Analysis | Python built-in function |

# %% [markdown]
# ## ⚠️ Common Beginner Mistake
#
# Many beginners think:
#
# ```python
# students.count()
# ```
#
# and
#
# ```python
# len(students)
# ```
#
# always return the same answer.
#
# This is true **only if there are no missing values**.

# %%
students = pd.Series([10,20,np.nan,40])

print("count():", students.count())
print("len():", len(students))
# Out:
# count(): 3
# len(): 4

# %% [markdown]
# ## 🏭 Real Industry Usage
#
# Suppose a hospital dataset contains patient blood pressure readings.
#
# Some patients missed their check-up.
#
# Before calculating statistics, analysts first check:
#
# ```python
# patients["BP"].count()
# ```
#
# to know how many valid readings are available.
#
# ---
#
# ## 👍 Pros
#
# - Ignores missing values automatically
# - Fast
# - Very useful in EDA
#
# ---
#
# ## 👎 Cons
#
# - Doesn't tell where missing values are
# - Doesn't count NaN values
#
# ---
#
# ## ⚠️ Edge Case
#
# If every value is NaN
#
# ```python
# pd.Series([np.nan,np.nan]).count()
# ```
#
# Output
#
# ```
# 0
# ```
#
# ---
#
# ## 🧠 Interview Question
#
# **Q:** What is the difference between `count()` and `len()`?
#
# **Answer:**
#
# - `count()` ignores missing values.
# - `len()` counts every element.

# %% [markdown]
# Create a Series containing 8 student marks.
#
# Replace two marks with `NaN`.
#
# Find:
#
# 1. Total values using `len()`
# 2. Valid values using `count()`
# 3. Explain the difference.

# %% [markdown]
# # Mini Challenge
#
# A company collected customer ratings.
#
# Some customers skipped giving ratings.
#
# Create a Series with at least **10 ratings**, including **3 NaN values**.
#
# Use:
#
# - `count()`
# - `len()`
#
# Compare the outputs and explain why they are different.

# %% [markdown]
# # 12.5 sum()
#
# ## 📖 Definition
#
# The `sum()` method returns the total of all numeric values in the Series.
#
# By default, it ignores missing values (`NaN`).
#
# ---
#
# ## 🤔 Why do we need it?
#
# In Data Analysis, we often need totals such as:
#
# - Total Sales
# - Total Revenue
# - Total Profit
# - Total Quantity Sold
# - Total Marks
#
# Instead of writing loops, Pandas calculates the total using a single method.
#
# ---
#
# ## 🧠 Think Like a Data Analyst
#
# Imagine you're analyzing the total sales made in a day.
#
# Instead of adding each sale manually, use:
#
# ```python
# sales.sum()
# ```
#
# This is faster, cleaner, and less error-prone.

# %%
import pandas as pd
import numpy as np

students = pd.Series(
    [92, 87, 78, 95, np.nan],
    index=["Rahul", "Priya", "Amit", "Sneha", "Kiran"],
    name="Marks"
)

students
# Out:
# Rahul    92.0
# Priya    87.0
# Amit     78.0
# Sneha    95.0
# Kiran     NaN
# Name: Marks, dtype: float64

# %%
students.sum()
# Out:
# np.float64(352.0)

# %% [markdown]
# ### 📤 Expected Output
#
# ```
# 352
# ```
#
# ---
#
# ### 🔍 Explanation
#
# ```
# 92
#
# +
#
# 87
#
# +
#
# 78
#
# +
#
# 95
#
# =
#
# 352
# ```
#
# `NaN` is ignored during the calculation.

# %%
pd.Series([10,20,np.nan,40]).sum()
# Out:
# np.float64(70.0)

# %% [markdown]
# ### Output
#
# ```
# 70
# ```
#
# Even though one value is `NaN`, Pandas ignores it by default.
#
# ---
#
# ## ⚠️ Common Beginner Mistake
#
# Many beginners think `NaN` makes the result `NaN`.
#
# By default,
#
# `sum()` skips missing values.
#
# ---
#
# ## 👍 Pros
#
# - Fast
# - Ignores missing values
# - Works on very large datasets
#
# ---
#
# ## 👎 Cons
#
# - Only meaningful for numeric data
#
# ---
#
# ## 🏭 Real Industry Usage
#
# Used to calculate:
#
# - Total monthly sales
# - Total orders
# - Total profit
# - Total electricity consumption
# - Total rainfall
#
# ---
#
# ## 🧠 Interview Question
#
# **Q:** Does `sum()` include missing values?
#
# **Answer:**
#
# No.
#
# It ignores `NaN` by default.

# %% [markdown]
# # Assignment
#
# Create a Series representing daily sales for one week.
#
# Calculate the total weekly sales using `sum()`.

# %% [markdown]
# # 12.6 mean()
#
# ## 📖 Definition
#
# The `mean()` method returns the arithmetic average of all numeric values in the Series.
#
# By default, it ignores missing values (`NaN`).
#
# ---
#
# ## 🤔 Why do we need it?
#
# The average helps us understand the overall trend of the data.
#
# It is one of the most commonly used statistical measures in:
#
# - Data Analysis
# - Machine Learning
# - Business Intelligence
# - Finance
# - Healthcare
#
# ---
#
# ## 🧠 Think Like a Data Scientist
#
# Suppose a teacher wants to know whether an exam was difficult.
#
# Instead of checking every student's marks, the teacher calculates the class average.
#
# That's exactly what `mean()` does.

# %%
students.mean()
# Out:
# np.float64(88.0)

# %% [markdown]
# ### 📤 Expected Output
#
# ```
# 88.0
# ```
#
# ---
#
# ### 🔍 Explanation
#
# ```
# (92 + 87 + 78 + 95)
#
# /
#
# 4
#
# =
#
# 88.0
# ```
#
# The missing value (`NaN`) is ignored.

# %% [markdown]
# ## ⚠️ Common Beginner Mistake
#
# Many beginners think the average is calculated using all rows.
#
# Actually,
#
# Pandas divides only by the number of **valid (non-null)** values.

# %%
print("Sum:", students.sum())
print("Count:", students.count())
print("Mean:", students.mean())
# Out:
# Sum: 352.0
# Count: 4
# Mean: 88.0

# %% [markdown]
# ### Output
#
# ```
# Sum: 352
#
# Count: 4
#
# Mean: 88.0
# ```
#
# Notice the relationship:
#
# ```
# Mean
#
# =
#
# Sum
#
# ÷
#
# Count
# ```
#
# This is a great way to verify whether your calculations are correct.

# %% [markdown]
# ## 🏭 Real Industry Usage
#
# The `mean()` method is used to calculate:
#
# - Average student marks
# - Average customer spending
# - Average employee salary
# - Average monthly sales
# - Average temperature
# - Average patient heart rate
#
# ---
#
# ## 👍 Pros
#
# - Easy to interpret
# - Widely used in statistics and ML
# - Ignores missing values automatically
#
# ---
#
# ## 👎 Cons
#
# - Sensitive to outliers
# - Not suitable for highly skewed data
#
# ---
#
# ## ⚠️ Edge Case
#
# If every value is `NaN`
#
# ```python
# pd.Series([np.nan,np.nan]).mean()
# ```
#
# Output
#
# ```
# NaN
# ```
#
# ---
#
# ## 🧠 Interview Question
#
# **Q:** How is `mean()` calculated in Pandas?
#
# **Answer:**
#
# ```
# Mean = Sum of non-null values ÷ Count of non-null values
# ```

# %% [markdown]
# # 12.7 median()
#
# ## 📖 Definition
#
# The `median()` method returns the **middle value** of a sorted Series.
#
# If the number of values is:
#
# - **Odd** → Returns the middle value.
# - **Even** → Returns the average of the two middle values.
#
# By default, missing values (`NaN`) are ignored.
#
# ---
#
# ## 🤔 Why do we need it?
#
# The median is useful when the dataset contains **outliers (extremely high or low values)**.
#
# Unlike the mean, the median is **not affected much by outliers**.
#
# ---
#
# ## 🧠 Think Like a Data Scientist
#
# Suppose a company's employee salaries are:
#
# ```
#
# 25000
# 28000
# 30000
# 32000
# 500000
#
# ```
#
# The CEO's salary (₹500000) is much higher than everyone else's.
#
# Using the **mean** gives a misleading average.
#
# Using the **median** gives the salary of a typical employee.

# %%
import pandas as pd
import numpy as np

students = pd.Series(
    [92, 87, 78, 95, 84],
    index=["Rahul", "Priya", "Amit", "Sneha", "Kiran"],
    name="Marks"
)

students
# Out:
# Rahul    92
# Priya    87
# Amit     78
# Sneha    95
# Kiran    84
# Name: Marks, dtype: int64

# %%
students.median()
# Out:
# np.float64(87.0)

# %% [markdown]
# ### 📤 Expected Output
#
# ```
# 87.0
# ```
#
# ---
#
# ### 🔍 Explanation
#
# Original values
#
# ```
# 92
# 87
# 78
# 95
# 84
# ```
#
# Sorted values
#
# ```
# 78
# 84
# 87
# 92
# 95
# ```
#
# The middle value is
#
# ```
# 87
# ```
#
# Therefore,
#
# ```
# Median = 87
# ```

# %%
marks = pd.Series([40, 50, 60, 70])

marks.median()
# Out:
# np.float64(55.0)

# %% [markdown]
# ### 📤 Expected Output
#
# ```
# 55.0
# ```
#
# ### 🔍 Explanation
#
# Sorted values
#
# ```
# 40
# 50
# 60
# 70
# ```
#
# Middle values
#
# ```
# 50
#
# 60
# ```
#
# Median
#
# ```
# (50 + 60) / 2
#
# =
#
# 55
# ```

# %%
salary = pd.Series([25000,28000,30000,32000,500000])

print("Mean :", salary.mean())
print("Median :", salary.median())
# Out:
# Mean : 123000.0
# Median : 30000.0

# %% [markdown]
# ## ⭐ Mean vs Median
#
# Output
#
# ```
# Mean   : 123000
#
# Median : 30000
# ```
#
# Notice that the CEO's salary increased the **mean** significantly.
#
# The **median** still represents the typical employee salary.
#
# This is why Data Scientists prefer **median** for skewed data.

# %% [markdown]
# ## ⚠️ Common Beginner Mistake
#
# Many beginners think:
#
# Median = Average
#
# This is incorrect.
#
# Mean = Average
#
# Median = Middle value after sorting.

# %% [markdown]
# ## 👍 Pros
#
# - Not affected much by outliers
# - Better for skewed datasets
# - Easy to interpret
#
# ## 👎 Cons
#
# - Doesn't use every value in the dataset
# - Less suitable for some mathematical calculations
#
# ## 🏭 Real Industry Usage
#
# Median is used in:
#
# - Salary Analysis
# - House Price Analysis
# - Income Distribution
# - Real Estate
# - Healthcare
#
# ## 🧠 Interview Question
#
# **Q:** When should we prefer median over mean?
#
# **Answer:**
#
# When the dataset contains outliers or is heavily skewed.

# %% [markdown]
# # 12.8 mode()
#
# ## 📖 Definition
#
# The `mode()` method returns the **most frequently occurring value** in a Series.
#
# Unlike `mean()` and `median()`, `mode()` can return **multiple values**.

# %%
scores = pd.Series([80,90,80,70,90,80])

scores
# Out:
# 0    80
# 1    90
# 2    80
# 3    70
# 4    90
# 5    80
# dtype: int64

# %%
scores.mode()
# Out:
# 0    80
# dtype: int64

# %% [markdown]
# ### 📤 Expected Output
#
# ```
# 0    80
# dtype: int64
# ```
#
# ### 🔍 Explanation
#
# Frequency
#
# ```
# 80 → 3 Times
#
# 90 → 2 Times
#
# 70 → 1 Time
# ```
#
# The most frequent value is
#
# ```
# 80
# ```

# %%
numbers = pd.Series([10,20,10,20,30])

numbers.mode()
# Out:
# 0    10
# 1    20
# dtype: int64

# %% [markdown]
# ## ⚠️ Common Beginner Mistake
#
# Many beginners expect only one mode.
#
# Actually,
#
# There can be multiple modes.
#
# Always remember,
#
# `mode()` returns a **Series**, not a single value.

# %% [markdown]
# ## 👍 Pros
#
# - Useful for categorical data
# - Can return multiple frequent values
# - Easy to understand
#
# ## 👎 Cons
#
# - May return multiple values
# - Less useful for continuous numerical data
#
# ## 🏭 Real Industry Usage
#
# Mode is used for:
#
# - Most sold product
# - Most common blood group
# - Most purchased mobile brand
# - Most visited website page
#
# ## 🧠 Interview Question
#
# **Q:** Why does `mode()` return a Series?
#
# **Answer:**
#
# Because there can be more than one mode.

# %% [markdown]
# # 12.9 max() and min()
#
# ## 📖 Definition
#
# - `max()` returns the largest value.
# - `min()` returns the smallest value.
#
# These methods ignore missing values (`NaN`) by default.

# %%
students.max()
# Out:
# np.int64(95)

# %%
students.min()
# Out:
# np.int64(78)

# %%
print("Highest Marks :", students.max())
print("Lowest Marks :", students.min())
# Out:
# Highest Marks : 95
# Lowest Marks : 78

# %% [markdown]
# ## ⚠️ Common Beginner Mistake
#
# Many beginners think
#
# ```python
# students.max()
# ```
#
# returns the student's name.
#
# Actually,
#
# It returns **only the maximum value**.
#
# To get the student name, use
#
# ```python
# students.idxmax()
# ```
#
# We'll learn this method next.

# %% [markdown]
# ## 👍 Pros
#
# - Very fast
# - Easy to use
# - Useful for quick analysis
#
# ## 👎 Cons
#
# - Returns only the value
# - Doesn't identify which record contains the value
#
# ## 🏭 Real Industry Usage
#
# Used to find:
#
# - Highest sales
# - Lowest temperature
# - Maximum profit
# - Minimum stock
#
# ## 🧠 Interview Question
#
# **Q:** What is the difference between `max()` and `idxmax()`?
#
# **Answer:**
#
# `max()` returns the maximum value.
#
# `idxmax()` returns the label (index) where the maximum value occurs.

# %% [markdown]
# # 📊 Mean vs Median vs Mode
#
# | Method | Returns | Best Used When |
# |---------|----------|----------------|
# | `mean()` | Average | Data has no major outliers |
# | `median()` | Middle value | Data contains outliers or is skewed |
# | `mode()` | Most frequent value | Finding the most common value or category |
#
# ---
#
# ## 🧠 Easy Memory Trick
#
# - **Mean** → Average of all values.
# - **Median** → Middle value after sorting.
# - **Mode** → Most frequently occurring value.
#
# Remember:
#
# **Average → Mean**
#
# **Middle → Median**
#
# **Most Frequent → Mode**

# %% [markdown]
# # 12.10 std()
#
# ## 📖 Definition
#
# The `std()` method returns the **Standard Deviation** of the values in a Series.
#
# Standard Deviation tells us **how much the data is spread out from the mean (average).**
#
# ---
#
# ## 🤔 Why do we need it?
#
# Knowing only the average is not enough.
#
# Consider these two classes:
#
# Class A Marks
#
# 80,81,79,80,80
#
# Average = 80
#
# Class B Marks
#
# 20,40,80,100,160
#
# Average = 80
#
# Both have the same average.
#
# But Class B has much larger variation.
#
# Standard Deviation measures this variation.
#
# ---
#
# ## 🧠 Think Like a Data Scientist
#
# Whenever we analyze data, we ask:
#
# "Are the values close to each other?"
#
# or
#
# "Are they spread out?"
#
# Standard Deviation answers this question.

# %%
students.std()
# Out:
# np.float64(6.685805860178712)

# %% [markdown]
# ### 📤 Expected Output
#
# ```
# 6.78233...
# ```
#
# (The exact value may vary slightly due to floating-point precision.)
#
# ---
#
# ### 🔍 Explanation
#
# - A **small** standard deviation means the marks are close to the average.
# - A **large** standard deviation means the marks are spread out.

# %%
marks1 = pd.Series([79,80,81,80,80])
marks2 = pd.Series([20,40,80,100,160])

print("Marks1 STD :", marks1.std())
print("Marks2 STD :", marks2.std())
# Out:
# Marks1 STD : 0.7071067811865476
# Marks2 STD : 54.772255750516614

# %% [markdown]
# ### 📊 Observation
#
# Both datasets have approximately the same average.
#
# However,
#
# - **Marks1** has a **small Standard Deviation** because the values are close together.
# - **Marks2** has a **large Standard Deviation** because the values are widely spread.
#
# ---
#
# ## ⚠️ Common Beginner Mistake
#
# Many beginners think:
#
# Higher Standard Deviation = Better Performance
#
# ❌ Wrong.
#
# It only means **more variation** in the data.
#
# ---
#
# ## 👍 Pros
#
# - Measures consistency
# - Detects variation
# - Important in Machine Learning
#
# ---
#
# ## 👎 Cons
#
# - Sensitive to outliers
# - Slightly harder to understand than mean
#
# ---
#
# ## 🏭 Real Industry Usage
#
# Used in:
#
# - Stock Market Risk Analysis
# - Quality Control
# - Student Performance Analysis
# - Medical Research
#
# ---
#
# ## 🧠 Interview Question
#
# **Q:** What does a low Standard Deviation indicate?
#
# **Answer:**
#
# The data points are close to the mean.

# %% [markdown]
# # 12.11 var()
#
# ## 📖 Definition
#
# The `var()` method returns the **Variance** of the Series.
#
# Variance is simply the **square of the Standard Deviation**.
#
# Formula
#
# Variance = (Standard Deviation)²
#
# ---
#
# ## 🤔 Why do we need it?
#
# Variance measures the spread of data mathematically.
#
# Many Machine Learning algorithms internally use variance calculations.

# %%
students.var()
# Out:
# np.float64(44.699999999999996)

# %%
print("STD :", students.std())
print("Variance :", students.var())
# Out:
# STD : 6.685805860178712
# Variance : 44.699999999999996

# %% [markdown]
# ## ⚠️ Common Beginner Mistake
#
# Many students confuse Variance with Standard Deviation.
#
# Remember:
#
# Variance
#
# ↓
#
# Squared Unit
#
# Standard Deviation
#
# ↓
#
# Original Unit
#
# Therefore,
#
# Standard Deviation is easier to interpret.

# %% [markdown]
# ## 👍 Pros
#
# - Important in statistics
# - Used in ML algorithms
# - Measures spread
#
# ## 👎 Cons
#
# - Harder to interpret because of squared units
#
# ---
#
# ## 🏭 Real Industry Usage
#
# Variance is used in
#
# - Machine Learning
# - Financial Risk
# - Scientific Research
# - Manufacturing Quality Control
#
# ---
#
# ## 🧠 Interview Question
#
# **Q:** What is the relationship between Variance and Standard Deviation?
#
# **Answer**
#
# Variance = (Standard Deviation)²

# %% [markdown]
# # 12.12 describe()
#
# ## 📖 Definition
#
# The `describe()` method generates a statistical summary of the Series.
#
# Instead of calling multiple methods individually,
#
# `describe()` gives all important statistics in one command.
#
# ---
#
# ## 🤔 Why do we need it?
#
# Data Scientists almost always run
#
# ```python
# df.describe()
# ```
#
# immediately after loading a dataset.
#
# It provides a quick overview of the data.

# %%
students.describe()
# Out:
# count     5.000000
# mean     87.200000
# std       6.685806
# min      78.000000
# 25%      84.000000
# 50%      87.000000
# 75%      92.000000
# max      95.000000
# Name: Marks, dtype: float64

# %% [markdown]
# ## 🔍 Understanding Every Value
#
# ### count
#
# Number of valid observations.
#
# ---
#
# ### mean
#
# Average of all values.
#
# ---
#
# ### std
#
# Standard Deviation.
#
# Measures data spread.
#
# ---
#
# ### min
#
# Smallest value.
#
# ---
#
# ### 25%
#
# First Quartile (Q1)
#
# 25% of observations are below this value.
#
# ---
#
# ### 50%
#
# Median
#
# ---
#
# ### 75%
#
# Third Quartile (Q3)
#
# 75% of observations are below this value.
#
# ---
#
# ### max
#
# Largest value.

# %%
print("Mean :", students.mean())
print("Median :", students.median())
print("Maximum :", students.max())
# Out:
# Mean : 87.2
# Median : 87.0
# Maximum : 95

# %% [markdown]
# Notice that all these values also appear inside `describe()`.
#
# That's why Data Scientists prefer
#
# ```python
# describe()
# ```
#
# instead of calling every statistical method separately.

# %% [markdown]
# ## ⚠️ Common Beginner Mistake
#
# Many beginners think
#
# ```python
# describe()
# ```
#
# works only for numbers.
#
# Actually,
#
# For categorical data,
#
# Pandas returns
#
# - count
# - unique
# - top
# - frequency

# %%
cities = pd.Series(["Delhi","Mumbai","Delhi","Bangalore"])

cities.describe()
# Out:
# count         4
# unique        3
# top       Delhi
# freq          2
# dtype: object

# %% [markdown]
# ## 👍 Pros
#
# - One command gives multiple statistics
# - Saves time
# - Widely used in EDA
#
# ## 👎 Cons
#
# - Doesn't include every statistical measure
# - Beginners may not understand quartiles immediately
#
# ---
#
# ## 🏭 Real Industry Usage
#
# Almost every Data Scientist begins Exploratory Data Analysis (EDA) with:
#
# ```python
# df.describe()
# ```
#
# before cleaning or modeling the data.
#
# ---
#
# ## 🧠 Interview Question
#
# **Q:** Why is `describe()` one of the first methods used in data analysis?
#
# **Answer:**
#
# Because it provides a quick statistical summary of the dataset, helping identify the distribution, spread, and possible anomalies before further analysis.

# %% [markdown]
# # 12.13 idxmax()
#
# ## 📖 Definition
#
# The `idxmax()` method returns the **index label** corresponding to the maximum value in a Series.
#
# Unlike `max()`, which returns the maximum value, `idxmax()` tells us **where that value is located**.
#
# ---
#
# ## 🤔 Why do we need it?
#
# In real-world datasets, knowing the maximum value is often not enough.
#
# For example,
#
# - Who scored the highest marks?
# - Which product had the highest sales?
# - Which city recorded the highest temperature?
#
# `idxmax()` helps us identify the corresponding record.
#
# ---
#
# ## 🧠 Think Like a Data Analyst
#
# Suppose you have monthly sales data.
#
# Knowing the highest sales amount is useful.
#
# But knowing **which month achieved those sales** is even more valuable.
#
# That's exactly what `idxmax()` provides.

# %%
import pandas as pd

students = pd.Series(
    [92,87,78,95,84],
    index=["Rahul","Priya","Amit","Sneha","Kiran"],
    name="Marks"
)

students
# Out:
# Rahul    92
# Priya    87
# Amit     78
# Sneha    95
# Kiran    84
# Name: Marks, dtype: int64

# %%
students.max()
# Out:
# np.int64(95)

# %%
students.idxmax()
# Out:
# 'Sneha'

# %% [markdown]
# ## ⭐ Difference Between max() and idxmax()
#
# | max() | idxmax() |
# |--------|----------|
# | Returns the maximum value | Returns the label of the maximum value |
# | Output → 95 | Output → Sneha |
# | Used when value is needed | Used when the corresponding record is needed |

# %%
print("Highest Marks :", students.max())
print("Topper :", students.idxmax())
# Out:
# Highest Marks : 95
# Topper : Sneha

# %% [markdown]
# ## 🔄 Alternative Approach

# %%
students[students == students.max()]
# Out:
# Sneha    95
# Name: Marks, dtype: int64

# %% [markdown]
# ## 👍 Pros
#
# - Quickly identifies the record with the maximum value.
# - Very useful in dashboards.
# - Cleaner than manual searching.
#
# ---
#
# ## 👎 Cons
#
# - Returns only the first occurrence if multiple maximum values exist.
# - Returns only the label, not the value.
#
# ---
#
# ## ⚠️ Edge Case
#
# Suppose
#
# ```
# Rahul    95
#
# Sneha    95
# ```
#
# Both students scored the highest marks.
#
# `idxmax()` returns
#
# ```
# Rahul
# ```
#
# because it always returns the **first occurrence**.

# %% [markdown]
# ## 🏭 Real Industry Usage
#
# `idxmax()` is commonly used to find:
#
# - 🏆 Top-performing employee
# - 📈 Best-selling product
# - 🌡️ Hottest city
# - 💰 Highest revenue month
# - 🎓 Class topper
#
# Instead of manually searching the data, analysts use `idxmax()` to identify the corresponding record instantly.

# %% [markdown]
# ## 🧠 Interview Corner
#
# ### Interview Questions
#
# **Q1. What is the difference between `max()` and `idxmax()`?**
#
# **Answer:**
#
# - `max()` returns the maximum value.
# - `idxmax()` returns the label where the maximum value occurs.
#
# ---
#
# **Q2. What happens if two values are tied for the maximum?**
#
# **Answer:**
#
# `idxmax()` returns the **first occurrence**.
#
# ---
#
# **Q3. Does `idxmax()` return the value or the index?**
#
# **Answer:**
#
# It returns the **index label**.

# %% [markdown]
# # 📝 Assignment
#
# Create a Series containing sales of five products.
#
# Perform the following:
#
# 1. Find the highest sales.
# 2. Find the product with the highest sales.
# 3. Print both the product name and sales amount.

# %% [markdown]
# # 🚀 Mini Challenge
#
# A cricket coach has the following player scores:
#
# Virat : 82
#
# Rohit : 95
#
# Gill : 77
#
# Rahul : 91
#
# Hardik : 88
#
# Tasks:
#
# ✅ Find the highest score.
#
# ✅ Find the player who scored the highest.
#
# ✅ Print the result in this format:
#
# Top Scorer : Rohit
#
# Runs : 95

# %% [markdown]
# # 12.14 idxmin()
#
# ## 📖 Definition
#
# The `idxmin()` method returns the **index label** corresponding to the minimum value in a Series.
#
# Unlike `min()`, which returns the minimum value, `idxmin()` tells us **where that minimum value is located**.
#
# ---
#
# ## 🤔 Why do we need it?
#
# In real-world datasets, knowing only the minimum value is often not enough.
#
# For example:
#
# - Which student scored the lowest marks?
# - Which product had the lowest sales?
# - Which city recorded the lowest temperature?
#
# `idxmin()` helps us identify the corresponding record.
#
# ---
#
# ## 🧠 Think Like a Data Analyst
#
# Suppose you're analyzing exam results.
#
# Knowing that the lowest mark is **78** is useful.
#
# But knowing **which student scored 78** helps you identify who may need additional support.
#
# That's exactly what `idxmin()` provides.

# %%
import pandas as pd

students = pd.Series(
    [92, 87, 78, 95, 84],
    index=["Rahul", "Priya", "Amit", "Sneha", "Kiran"],
    name="Marks"
)

students
# Out:
# Rahul    92
# Priya    87
# Amit     78
# Sneha    95
# Kiran    84
# Name: Marks, dtype: int64

# %%
students.min()
# Out:
# np.int64(78)

# %%
students.idxmin()
# Out:
# 'Amit'

# %% [markdown]
# ## ⭐ Difference Between min() and idxmin()
#
# | min() | idxmin() |
# |--------|----------|
# | Returns the minimum value | Returns the label of the minimum value |
# | Output → 78 | Output → Amit |
# | Used when value is needed | Used when the corresponding record is needed |

# %%
print("Lowest Marks :", students.min())
print("Student :", students.idxmin())
# Out:
# Lowest Marks : 78
# Student : Amit

# %% [markdown]
# ## 🔄 Alternative Approach

# %%
students[students == students.min()]
# Out:
# Amit    78
# Name: Marks, dtype: int64

# %% [markdown]
# ## 👍 Pros
#
# - Quickly identifies the record with the minimum value.
# - Cleaner than manually searching.
# - Frequently used in data analysis and reporting.
#
# ---
#
# ## 👎 Cons
#
# - Returns only the first occurrence if multiple minimum values exist.
# - Returns only the label, not the value.
#
# ---
#
# ## ⚠️ Edge Case
#
# Suppose the data is:
#
# Rahul → 78
#
# Amit → 78
#
# Priya → 90
#
# Both Rahul and Amit have the minimum value.
#
# `idxmin()` returns:
#
# Rahul
#
# because it always returns the **first occurrence** of the minimum value.

# %% [markdown]
# ## 🏭 Real Industry Usage
#
# `idxmin()` is commonly used to identify:
#
# - 📉 Lowest-performing employee
# - 🛒 Least-selling product
# - 🌡️ Coldest city
# - 📦 Product with minimum stock
# - 🎓 Student with the lowest marks
#
# Instead of manually searching the data, analysts use `idxmin()` to quickly identify the corresponding record.

# %% [markdown]
# ## 🧠 Interview Corner
#
# ### Q1. What is the difference between `min()` and `idxmin()`?
#
# **Answer:**
#
# - `min()` returns the minimum value.
# - `idxmin()` returns the index label where the minimum value occurs.
#
# ---
#
# ### Q2. What happens if two values are tied for the minimum?
#
# **Answer:**
#
# `idxmin()` returns the **first occurrence**.
#
# ---
#
# ### Q3. Does `idxmin()` return the value or the index?
#
# **Answer:**
#
# It returns the **index label**.

# %% [markdown]
# # 📝 Assignment
#
# Create a Series containing the monthly sales of five stores.
#
# Perform the following:
#
# 1. Find the minimum sales.
# 2. Find the store with the minimum sales.
# 3. Print both the store name and sales amount.

# %% [markdown]
# # 🚀 Mini Challenge
#
# A company recorded the following monthly sales (in ₹):
#
# Store A : 45000
#
# Store B : 52000
#
# Store C : 38000
#
# Store D : 61000
#
# Store E : 47000
#
# Tasks:
#
# ✅ Find the minimum sales.
#
# ✅ Find the store with the minimum sales.
#
# ✅ Display the result in the following format:
#
# Lowest Sales Store : Store C
#
# Sales : ₹38000

# %% [markdown]
# # 🧠 Easy Way to Remember
#
# max()     → Maximum Value
#
# idxmax()  → Index of Maximum Value
#
# min()     → Minimum Value
#
# idxmin()  → Index of Minimum Value

# %% [markdown]
# # 12.15 sort_values()
#
# ## 📖 Definition
#
# The `sort_values()` method sorts the values in a Series in **ascending or descending order**.
#
# By default, it sorts the values in **ascending order**.
#
# ---
#
# ## 🤔 Why do we need it?
#
# In real-world data analysis, we often need to:
#
# - Find top-performing students
# - Rank products by sales
# - Arrange employee salaries
# - Display highest profits first
# - Analyze data from lowest to highest
#
# Instead of manually arranging the data, Pandas provides the `sort_values()` method.
#
# ---
#
# ## 🧠 Think Like a Data Analyst
#
# Imagine you have sales data for different products.
#
# Before creating a report, you want to display the products from the highest-selling to the lowest-selling.
#
# That's exactly what `sort_values()` helps you do.

# %%
import pandas as pd

students = pd.Series(
    [92, 87, 78, 95, 84],
    index=["Rahul", "Priya", "Amit", "Sneha", "Kiran"],
    name="Marks"
)

students
# Out:
# Rahul    92
# Priya    87
# Amit     78
# Sneha    95
# Kiran    84
# Name: Marks, dtype: int64

# %%
students.sort_values()
# Out:
# Amit     78
# Kiran    84
# Priya    87
# Rahul    92
# Sneha    95
# Name: Marks, dtype: int64

# %% [markdown]
# ### 🔍 Explanation
#
# The values are sorted from **smallest to largest**.
#
# Notice that the **student names move along with their marks** because they are the index labels corresponding to those values.

# %%
students.sort_values(ascending=False)
# Out:
# Sneha    95
# Rahul    92
# Priya    87
# Kiran    84
# Amit     78
# Name: Marks, dtype: int64

# %% [markdown]
# ### 🔍 Explanation
#
# Setting `ascending=False` sorts the values from **highest to lowest**.
#
# This is commonly used to display rankings, such as top scorers or highest-selling products.

# %%
students.sort_values(ignore_index=True)
# Out:
# 0    78
# 1    84
# 2    87
# 3    92
# 4    95
# Name: Marks, dtype: int64

# %% [markdown]
# ### 🔍 Explanation
#
# Normally, the original index labels (`Rahul`, `Priya`, etc.) are preserved.
#
# By using `ignore_index=True`, Pandas creates a **new integer index** starting from `0`.

# %%
temp = students.copy()

temp.sort_values(inplace=True)

temp
# Out:
# Amit     78
# Kiran    84
# Priya    87
# Rahul    92
# Sneha    95
# Name: Marks, dtype: int64

# %% [markdown]
# ## 🔍 What does `inplace=True` do?
#
# Normally, `sort_values()` returns a **new sorted Series** and leaves the original unchanged.
#
# When you use:
#
# ```python
# inplace=True
# ```
#
# the original Series itself is modified.
#
# Use `inplace=True` only when you are sure you no longer need the original order.

# %% [markdown]
# ## ⚠️ Common Beginner Mistakes
#
# ### ❌ Mistake 1
#
# Many beginners think:
#
# ```python
# students.sort_values()
# ```
#
# permanently changes the original Series.
#
# It does **not**.
#
# It returns a **new sorted Series**.
#
# To modify the original, either:
#
# - Assign the result back:
#
# ```python
# students = students.sort_values()
# ```
#
# or
#
# - Use:
#
# ```python
# students.sort_values(inplace=True)
# ```

# %% [markdown]
# ## 👍 Pros
#
# - Very easy to rank data
# - Supports ascending and descending order
# - Useful for reports and dashboards
#
# ---
#
# ## 👎 Cons
#
# - Creates a new object unless `inplace=True` is used
# - Sorting very large datasets can take time
#
# ---
#
# ## ⚠️ Edge Case
#
# If multiple values are the same, they appear together in the sorted output.
#
# Example:
#
# ```
# Rahul → 90
#
# Priya → 90
#
# Amit → 85
# ```
#
# Both Rahul and Priya will appear together because they have equal values.

# %% [markdown]
# ## 🏭 Real Industry Usage
#
# `sort_values()` is used to:
#
# - 🏆 Rank students by marks
# - 💰 Sort products by sales
# - 📈 Display highest profits first
# - 📦 Arrange inventory by stock
# - ⭐ Show highest-rated products

# %% [markdown]
# ## 🧠 Interview Corner
#
# ### Q1. What is the default sorting order in `sort_values()`?
#
# **Answer:**
#
# Ascending order.
#
# ---
#
# ### Q2. How do you sort in descending order?
#
# **Answer:**
#
# ```python
# students.sort_values(ascending=False)
# ```
#
# ---
#
# ### Q3. Does `sort_values()` modify the original Series?
#
# **Answer:**
#
# No.
#
# Unless `inplace=True` is used.

# %% [markdown]
# # 📝 Assignment
#
# Create a Series containing monthly sales of five stores.
#
# Perform the following:
#
# 1. Sort the sales in ascending order.
# 2. Sort the sales in descending order.
# 3. Reset the index using `ignore_index=True`.
# 4. Try using `inplace=True` on a copy of the Series and observe the result.

# %% [markdown]
# # 🚀 Mini Challenge
#
# Create a Series of IPL players and their runs.
#
# Tasks:
#
# ✅ Display the runs in ascending order.
#
# ✅ Display the runs in descending order.
#
# ✅ Identify the player with the highest runs using `idxmax()`.
#
# ✅ Identify the player with the lowest runs using `idxmin()`.

# %% [markdown]
# # 12.16 sort_index()
#
# ## 📖 Definition
#
# The `sort_index()` method sorts a Series based on its **index labels**, not on its values.
#
# By default, it sorts the index labels in **ascending order**.
#
# ---
#
# ## 🤔 Why do we need it?
#
# Sometimes, the data values are already correct, but the index labels are not in the desired order.
#
# For example:
#
# - Sorting student names alphabetically.
# - Sorting months in a specific order.
# - Organizing product IDs.
# - Cleaning data after combining multiple datasets.
#
# Instead of sorting the values, we sort the **index labels**.
#
# ---
#
# ## 🧠 Think Like a Data Analyst
#
# Imagine you receive sales data from different branches.
#
# The branch names are not arranged alphabetically.
#
# Before creating a report, you organize the branch names using `sort_index()`.

# %%
import pandas as pd

students = pd.Series(
    [92, 87, 78, 95, 84],
    index=["Rahul", "Priya", "Amit", "Sneha", "Kiran"],
    name="Marks"
)

students
# Out:
# Rahul    92
# Priya    87
# Amit     78
# Sneha    95
# Kiran    84
# Name: Marks, dtype: int64

# %%
students.sort_index()
# Out:
# Amit     78
# Kiran    84
# Priya    87
# Rahul    92
# Sneha    95
# Name: Marks, dtype: int64

# %% [markdown]
# ## 🔍 Explanation
#
# The **student names (index labels)** are sorted alphabetically.
#
# Notice that:
#
# - The marks **do not get sorted**.
# - Each mark stays attached to its correct student.
#
# Only the **order of the index labels** changes.

# %%
students.sort_index(ascending=False)
# Out:
# Sneha    95
# Rahul    92
# Priya    87
# Kiran    84
# Amit     78
# Name: Marks, dtype: int64

# %% [markdown]
# ## 🔍 Explanation
#
# Using
#
# ```python
# ascending=False
# ```
#
# sorts the index labels in **reverse alphabetical order**.

# %%
temp = students.copy()

temp.sort_index(inplace=True)

temp
# Out:
# Amit     78
# Kiran    84
# Priya    87
# Rahul    92
# Sneha    95
# Name: Marks, dtype: int64

# %% [markdown]
# ## 🔍 What does `inplace=True` do?
#
# Normally,
#
# ```python
# students.sort_index()
# ```
#
# returns a **new sorted Series**.
#
# The original Series remains unchanged.
#
# Using
#
# ```python
# inplace=True
# ```
#
# modifies the original Series directly.
#
# Use this carefully because the original order cannot be recovered unless you have another copy.

# %% [markdown]
# ## ⭐ Difference Between `sort_values()` and `sort_index()`
#
# | sort_values() | sort_index() |
# |---------------|--------------|
# | Sorts the **values** | Sorts the **index labels** |
# | 78 → 95 | Amit → Sneha |
# | Used for ranking | Used for organizing labels |
#
# ### Example
#
# Original
#
# ```
# Rahul → 92
# Priya → 87
# Amit → 78
# Sneha → 95
# Kiran → 84
# ```
#
# ### `sort_values()`
#
# ```
# Amit → 78
# Kiran → 84
# Priya → 87
# Rahul → 92
# Sneha → 95
# ```
#
# ### `sort_index()`
#
# ```
# Amit → 78
# Kiran → 84
# Priya → 87
# Rahul → 92
# Sneha → 95
# ```
#
# ⚠️ **Important:** In this example, both outputs **look the same by coincidence** because the marks increase in the same order as the names after sorting.
#
# Don't assume this always happens!

# %%
students2 = pd.Series(
    [55, 95, 80, 70, 90],
    index=["Rahul", "Priya", "Amit", "Sneha", "Kiran"]
)

print("Original Series")
print(students2)

print("\nSorted by Values")
print(students2.sort_values())

print("\nSorted by Index")
print(students2.sort_index())
# Out:
# Original Series
# Rahul    55
# Priya    95
# Amit     80
# Sneha    70
# Kiran    90
# dtype: int64
#
# Sorted by Values
# Rahul    55
# Sneha    70
# Amit     80
# Kiran    90
# Priya    95
# dtype: int64
#
# Sorted by Index
# Amit     80
# Kiran    90
# Priya    95
# Rahul    55
# Sneha    70
# dtype: int64

# %% [markdown]
# ## ⚠️ Common Beginner Mistakes
#
# ### ❌ Mistake 1
#
# Thinking `sort_index()` sorts the values.
#
# It **does not**.
#
# It only sorts the **index labels**.
#
# ---
#
# ### ❌ Mistake 2
#
# Expecting the original Series to change automatically.
#
# Remember:
#
# ```python
# students.sort_index()
# ```
#
# returns a new Series.
#
# Use:
#
# ```python
# students = students.sort_index()
# ```
#
# or
#
# ```python
# students.sort_index(inplace=True)
# ```
#
# if you want to modify the original.

# %% [markdown]
# ## 👍 Pros
#
# - Organizes labels neatly.
# - Useful after merging or concatenating data.
# - Improves readability.
#
# ---
#
# ## 👎 Cons
#
# - Does not rank values.
# - Creates a new object unless `inplace=True` is used.
#
# ---
#
# ## ⚠️ Edge Case
#
# If the index contains duplicate labels,
#
# ```python
# students = pd.Series(
#     [90, 80, 70],
#     index=["A", "A", "B"]
# )
# ```
#
# `sort_index()` still works.
#
# The duplicate labels remain together after sorting.

# %% [markdown]
# ## 🏭 Real Industry Usage
#
# `sort_index()` is commonly used to:
#
# - Arrange customer IDs.
# - Organize branch names.
# - Sort dates after importing data.
# - Improve report readability.
# - Prepare datasets before exporting them.

# %% [markdown]
# ## 🧠 Interview Corner
#
# ### Q1. What is the difference between `sort_values()` and `sort_index()`?
#
# **Answer:**
#
# - `sort_values()` sorts the values.
# - `sort_index()` sorts the index labels.
#
# ---
#
# ### Q2. What is the default sorting order?
#
# **Answer:**
#
# Ascending.
#
# ---
#
# ### Q3. Does `sort_index()` change the original Series?
#
# **Answer:**
#
# No.
#
# It returns a new Series unless `inplace=True` is used.

# %% [markdown]
# # 📝 Assignment
# Create a Series with the following data:
#
# ```
# Delhi      120
# Mumbai     180
# Bangalore  150
# Chennai    140
# Hyderabad  160
# ```
#
# Perform the following:
#
# 1. Sort the Series by index.
# 2. Sort the index in descending order.
# 3. Observe that the values remain associated with their respective cities.

# %% [markdown]
# # 🚀 Mini Challenge
#
# A company stores employee IDs as the index and salaries as the values.
#
# Create a Series for five employees.
#
# Tasks:
#
# ✅ Sort by salary using `sort_values()`.
#
# ✅ Sort by employee ID using `sort_index()`.
#
# ✅ Explain the difference between the two outputs in your own words.
